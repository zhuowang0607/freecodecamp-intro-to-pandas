# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas DataFrame exercises

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 2.2.2

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# # **DataFrame creation**

# %% [markdown]
# ### Create an empty pandas DataFrame

# %%
# your code goes here
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame(data=[None],
             index=[None],
             columns=[None])
# Out:
#       None
# None  None

# %% [markdown]
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968],
    ['Falcon', 'male', 1961],
    ['Winter Soldier', 'male', 1967],
]

# %%
marvel_df = pd.DataFrame(data=marvel_data)

marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968
# 20            Falcon    male  1961
# 21    Winter Soldier    male  1967

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add column names to the `marvel_df`

# %%
col_names = ['Name', 'Sex', 'Year']

marvel_df.columns = col_names
marvel_df
# Out:
#                 Name     Sex  Year
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968
# 20            Falcon    male  1961
# 21    Winter Soldier    male  1967

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add index names to the `marvel_df` (use the character name as index)

# %%
marvel_df.set_index('Name')
# Out:
#                      Sex  Year
# Name
# Spider-Man          male  1962
# Captain America     male  1941
# Wolverine           male  1974
# Iron Man            male  1963
# Thor                male  1963
# Thing               male  1961
# Mister Fantastic    male  1961
# Hulk                male  1962
# Beast               male  1963
# Invisible Woman   female  1961
# Storm             female  1975
# Namor               male  1939
# Hawkeye             male  1964
# Daredevil           male  1964
# Doctor Strange      male  1963
# Hank Pym            male  1962
# Scarlet Witch     female  1964
# Wasp              female  1963
# Black Widow       female  1964
# Vision              male  1968
# Falcon              male  1961
# Winter Soldier      male  1967

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop the name column as it's now the index

# %%
marvel_df.drop(columns=['Name'])
# marvel_df = marvel_df.drop(['name'], axis=1)
# marvel_df
# Out:
#        Sex  Year
# 0     male  1962
# 1     male  1941
# 2     male  1974
# 3     male  1963
# 4     male  1963
# 5     male  1961
# 6     male  1961
# 7     male  1962
# 8     male  1963
# 9   female  1961
# 10  female  1975
# 11    male  1939
# 12    male  1964
# 13    male  1964
# 14    male  1963
# 15    male  1962
# 16  female  1964
# 17  female  1963
# 18  female  1964
# 19    male  1968
# 20    male  1961
# 21    male  1967

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop 'Namor' and 'Hank Pym' rows

# %%
marvel_df
# Out:
#                 Name     Sex  Year
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968
# 20            Falcon    male  1961
# 21    Winter Soldier    male  1967

# %%
marvel_df['Name'].isin(['Namor','Hank Pym'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# Name: Name, dtype: bool

# %%
marvel_df.loc[marvel_df['Name'].isin(['Namor','Hank Pym'])]
# Out:
#         Name   Sex  Year
# 11     Namor  male  1939
# 15  Hank Pym  male  1962

# %%
index_to_go = marvel_df[marvel_df['Name'].isin(['Namor','Hank Pym'])].index
index_to_go
# Out:
# Index([11, 15], dtype='int64')

# %%
marvel_df.drop(index=index_to_go)
# Out:
#                 Name     Sex  Year
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968
# 20            Falcon    male  1961
# 21    Winter Soldier    male  1967

# %%
marvel_df.drop(marvel_df[marvel_df['Name'].isin(['Namor','Hank Pym'])].index,axis = 0)
# Out:
#                 Name     Sex  Year
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968
# 20            Falcon    male  1961
# 21    Winter Soldier    male  1967

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ### Show the first 5 elements on `marvel_df`

# %%
# your code goes here
marvel_df.head()
# Out:
#               Name   Sex  Year
# 0       Spider-Man  male  1962
# 1  Captain America  male  1941
# 2        Wolverine  male  1974
# 3         Iron Man  male  1963
# 4             Thor  male  1963

# %%
#marvel_df.loc[['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor'], :] # bad!
#marvel_df.loc['Spider-Man': 'Thor', :]
#marvel_df.iloc[0:5, :]
#marvel_df.iloc[0:5,]
marvel_df.iloc[:5,:]
#marvel_df.head()
# Out:
#               Name   Sex  Year
# 0       Spider-Man  male  1962
# 1  Captain America  male  1941
# 2        Wolverine  male  1974
# 3         Iron Man  male  1963
# 4             Thor  male  1963

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the last 5 elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[-5:]
# Out:
#               Name     Sex  Year
# 17            Wasp  female  1963
# 18     Black Widow  female  1964
# 19          Vision    male  1968
# 20          Falcon    male  1961
# 21  Winter Soldier    male  1967

# %%
#marvel_df.loc[['Hank Pym', 'Scarlet Witch', 'Wasp', 'Black Widow', 'Vision'], :] # bad!
#marvel_df.loc['Hank Pym':'Vision', :]
#marvel_df.iloc[-5:,]
marvel_df.tail()
# Out:
#               Name     Sex  Year
# 17            Wasp  female  1963
# 18     Black Widow  female  1964
# 19          Vision    male  1968
# 20          Falcon    male  1961
# 21  Winter Soldier    male  1967

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show just the sex of the first 5 elements on `marvel_df`

# %%
marvel_df.set_index('Name',inplace=True)

# %%
marvel_df
# Out:
#                      Sex  Year
# Name
# Spider-Man          male  1962
# Captain America     male  1941
# Wolverine           male  1974
# Iron Man            male  1963
# Thor                male  1963
# Thing               male  1961
# Mister Fantastic    male  1961
# Hulk                male  1962
# Beast               male  1963
# Invisible Woman   female  1961
# Storm             female  1975
# Namor               male  1939
# Hawkeye             male  1964
# Daredevil           male  1964
# Doctor Strange      male  1963
# Hank Pym            male  1962
# Scarlet Witch     female  1964
# Wasp              female  1963
# Black Widow       female  1964
# Vision              male  1968
# Falcon              male  1961
# Winter Soldier      male  1967

# %%
# your code goes here
marvel_df.iloc[:5]['Sex'].to_frame()
# Out:
#                   Sex
# Name
# Spider-Man       male
# Captain America  male
# Wolverine        male
# Iron Man         male
# Thor             male

# %% [markdown]
#  sa

# %%
marvel_df.iloc[:5, 1].to_frame()
# Out:
#                  Year
# Name
# Spider-Man       1962
# Captain America  1941
# Wolverine        1974
# Iron Man         1963
# Thor             1963

# %%
#marvel_df.iloc[:5,]['sex'].to_frame()
marvel_df.iloc[:5,].Sex.to_frame()
#marvel_df.head().sex.to_frame()
# Out:
#                   Sex
# Name
# Spider-Man       male
# Captain America  male
# Wolverine        male
# Iron Man         male
# Thor             male

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first_appearance of all middle elements on `marvel_df`

# %%
# your code goes here
marvel_df.iloc[1:-1,][['Year']]
# Out:
#                   Year
# Name
# Captain America   1941
# Wolverine         1974
# Iron Man          1963
# Thor              1963
# Thing             1961
# Mister Fantastic  1961
# Hulk              1962
# Beast             1963
# Invisible Woman   1961
# Storm             1975
# Namor             1939
# Hawkeye           1964
# Daredevil         1964
# Doctor Strange    1963
# Hank Pym          1962
# Scarlet Witch     1964
# Wasp              1963
# Black Widow       1964
# Vision            1968
# Falcon            1961

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first and last elements on `marvel_df`

# %%
#marvel_df.iloc[[0, -1],][['sex', 'first_appearance']]
marvel_df.iloc[[0, -1]]
# Out:
#                  Sex  Year
# Name
# Spider-Man      male  1962
# Winter Soldier  male  1967

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame manipulation and operations

# %% [markdown]
# ### Modify the `first_appearance` of 'Vision' to year 1964

# %%
marvel_df.loc['Vision','Year'] = 1964

marvel_df
# Out:
#                      Sex  Year
# Name
# Spider-Man          male  1962
# Captain America     male  1941
# Wolverine           male  1974
# Iron Man            male  1963
# Thor                male  1963
# Thing               male  1961
# Mister Fantastic    male  1961
# Hulk                male  1962
# Beast               male  1963
# Invisible Woman   female  1961
# Storm             female  1975
# Namor               male  1939
# Hawkeye             male  1964
# Daredevil           male  1964
# Doctor Strange      male  1963
# Hank Pym            male  1962
# Scarlet Witch     female  1964
# Wasp              female  1963
# Black Widow       female  1964
# Vision              male  1964
# Falcon              male  1961
# Winter Soldier      male  1967

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
# your code goes here
from datetime import date

# %%
today = date.today()
today.year
# Out:
# 2025

# %%
marvel_df['Years_since'] = today.year - marvel_df['Year']

marvel_df
# Out:
#                      Sex  Year  Years_since
# Name
# Spider-Man          male  1962           63
# Captain America     male  1941           84
# Wolverine           male  1974           51
# Iron Man            male  1963           62
# Thor                male  1963           62
# Thing               male  1961           64
# Mister Fantastic    male  1961           64
# Hulk                male  1962           63
# Beast               male  1963           62
# Invisible Woman   female  1961           64
# Storm             female  1975           50
# Namor               male  1939           86
# Hawkeye             male  1964           61
# Daredevil           male  1964           61
# Doctor Strange      male  1963           62
# Hank Pym            male  1962           63
# Scarlet Witch     female  1964           61
# Wasp              female  1963           62
# Black Widow       female  1964           61
# Vision              male  1964           61
# Falcon              male  1961           64
# Winter Soldier      male  1967           58

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame boolean arrays (also called masks)

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
mask = marvel_df['Sex'] == 'female'

mask
# Out:
# Name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Namor               False
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Falcon              False
# Winter Soldier      False
# Name: Sex, dtype: bool

# %%
marvel_df[mask]
# Out:
#                     Sex  Year  Years_since
# Name
# Invisible Woman  female  1961           64
# Storm            female  1975           50
# Scarlet Witch    female  1964           61
# Wasp             female  1963           62
# Black Widow      female  1964           61

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the male characters

# %%
mask = marvel_df['Sex'] == 'male'

marvel_df[mask]
# Out:
#                    Sex  Year  Years_since
# Name
# Spider-Man        male  1962           63
# Captain America   male  1941           84
# Wolverine         male  1974           51
# Iron Man          male  1963           62
# Thor              male  1963           62
# Thing             male  1961           64
# Mister Fantastic  male  1961           64
# Hulk              male  1962           63
# Beast             male  1963           62
# Namor             male  1939           86
# Hawkeye           male  1964           61
# Daredevil         male  1964           61
# Doctor Strange    male  1963           62
# Hank Pym          male  1962           63
# Vision            male  1964           61
# Falcon            male  1961           64
# Winter Soldier    male  1967           58

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` after 1970

# %%
mask = marvel_df['Year'] > 1970

marvel_df[mask]
# Out:
#               Sex  Year  Years_since
# Name
# Wolverine    male  1974           51
# Storm      female  1975           50

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the female characters with `first_appearance` after 1970

# %%
mask = (marvel_df['Sex'] == 'female') & (marvel_df['Year'] > 1970)

marvel_df[mask]
# Out:
#           Sex  Year  Years_since
# Name
# Storm  female  1975           50

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame summary statistics

# %% [markdown]
# ### Show basic statistics of `marvel_df`

# %%
marvel_df.describe()
# Out:
#               Year  Years_since
# count    22.000000    22.000000
# mean   1961.863636    63.136364
# std       7.977919     7.977919
# min    1939.000000    50.000000
# 25%    1961.250000    61.000000
# 50%    1963.000000    62.000000
# 75%    1964.000000    63.750000
# max    1975.000000    86.000000

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the mean value of `first_appearance`

# %%
#np.mean(marvel_df.first_appearance)
marvel_df['Year'].mean()
# Out:
# np.float64(1961.8636363636363)

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
#np.min(marvel_df.first_appearance)
marvel_df.Year.min()
# Out:
# 1939

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with the min value of `first_appearance`

# %%
mask = marvel_df['Year'] == marvel_df.Year.min()
marvel_df[mask]
# Out:
#         Sex  Year  Years_since
# Name
# Namor  male  1939           86

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame basic plottings

# %% [markdown]
# ### Reset index names of `marvel_df`

# %%
marvel_df = marvel_df.reset_index()

marvel_df
# Out:
#                 Name     Sex  Year  Years_since
# 0         Spider-Man    male  1962           63
# 1    Captain America    male  1941           84
# 2          Wolverine    male  1974           51
# 3           Iron Man    male  1963           62
# 4               Thor    male  1963           62
# 5              Thing    male  1961           64
# 6   Mister Fantastic    male  1961           64
# 7               Hulk    male  1962           63
# 8              Beast    male  1963           62
# 9    Invisible Woman  female  1961           64
# 10             Storm  female  1975           50
# 11             Namor    male  1939           86
# 12           Hawkeye    male  1964           61
# 13         Daredevil    male  1964           61
# 14    Doctor Strange    male  1963           62
# 15          Hank Pym    male  1962           63
# 16     Scarlet Witch  female  1964           61
# 17              Wasp  female  1963           62
# 18       Black Widow  female  1964           61
# 19            Vision    male  1964           61
# 20            Falcon    male  1961           64
# 21    Winter Soldier    male  1967           58

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot the values of `first_appearance`

# %%
# your code goes here
plt.plot(marvel_df.index, marvel_df.Year)

# %%
#plt.plot(marvel_df.index, marvel_df.first_appearance)
marvel_df.Year.plot()
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot a histogram (plot.hist) with values of `first_appearance`

# %%
plt.hist(marvel_df.Year)
# Out:
# (array([ 2.,  0.,  0.,  0.,  0.,  0., 17.,  1.,  0.,  2.]),
#  array([1939. , 1942.6, 1946.2, 1949.8, 1953.4, 1957. , 1960.6, 1964.2,
#         1967.8, 1971.4, 1975. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
